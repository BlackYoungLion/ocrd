# %%
import easyocr

# %%
reader = easyocr.Reader(['en','ru'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL

# %%
from PIL import ImageDraw
#im = PIL.Image.open('invoice1.png')
#im = PIL.Image.open('france.jfif')
#im = PIL.Image.open('1.png')
im = PIL.Image.open('eC-dulTAyEQ.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=609x599 at 0x17E8276CFD0>

# %%
bounds = reader.readtext('eC-dulTAyEQ.jpg')
#bounds = reader.readtext('france.jfif')
bounds
# Out:
# [([[391, 263], [516, 263], [516, 306], [391, 306]],
#   'молодой',
#   0.9538118243217468),
#  ([[351.15350102802535, 283.1219034952862],
#    [461.9792665231932, 296.6479048654408],
#    [457.84649897197465, 322.8780965047138],
#    [346.0207334768068, 310.3520951345592]],
#   'ЧЕловек,',
#   0.282868355512619),
#  ([[462, 296], [553, 296], [553, 329], [462, 329]],
#   'АЧТо у',
#   0.11308220028877258),
#  ([[379, 315], [520, 315], [520, 352], [379, 352]],
#   'BАС 8 Этом',
#   0.10162421315908432),
#  ([[379, 337], [514, 337], [514, 377], [379, 377]],
#   'ПАКЕТиКE?',
#   0.2830055058002472)]

# %%
for i in bounds:
    print(i[1])
# Out:
# молодой
# ЧЕловек,
# АЧТо у
# BАС 8 Этом
# ПАКЕТиКE?

# %%
def  draw_boxes(image,bounds,color='yellow',width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0,*p1,*p2,*p3,*p0], fill=color,width=width)
    return image

draw_boxes(im,bounds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\soft\envs\env_easyocr\lib\site-packages\PIL\ImagePalette.py in getcolor(self, color)
#      98             try:
# ---> 99                 return self.colors[color]
#     100             except KeyError as e:
#
# KeyError: (255, 255, 0)
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-ccfe2081641f> in <module>
#       6     return image
#       7
# ----> 8 draw_boxes(im,bounds)
#
# <ipython-input-48-ccfe2081641f> in draw_boxes(image, bounds, color, width)
#       3     for bound in bounds:
#       4         p0, p1, p2, p3 = bound[0]
# ----> 5         draw.line([*p0,*p1,*p2,*p3,*p0], fill=color,width=width)
#       6     return image
#       7
#
# d:\soft\envs\env_easyocr\lib\site-packages\PIL\ImageDraw.py in line(self, xy, fill, width, joint)
#     152     def line(self, xy, fill=None, width=0, joint=None):
#     153         """Draw a line, or a connected sequence of line segments."""
# --> 154         ink = self._getink(fill)[0]
#     155         if ink is not None:
#     156             self.draw.draw_lines(xy, ink, width)
#
# d:\soft\envs\env_easyocr\lib\site-packages\PIL\ImageDraw.py in _getink(self, ink, fill)
#     109                     ink = ImageColor.getcolor(ink, self.mode)
#     110                 if self.palette and not isinstance(ink, numbers.Number):
# --> 111                     ink = self.palette.getcolor(ink)
#     112                 ink = self.draw.draw_ink(ink)
#     113             if fill is not None:
#
# d:\soft\envs\env_easyocr\lib\site-packages\PIL\ImagePalette.py in getcolor(self, color)
#     107                 self.colors[color] = index
#     108                 self.palette[index] = color[0]
# --> 109                 self.palette[index + 256] = color[1]
#     110                 self.palette[index + 512] = color[2]
#     111                 self.dirty = 1
#
# IndexError: bytearray index out of range

# %%
for i in bounds:
    print(i[1])
# Out:
# БитДк
# сливайте
# глупцы
