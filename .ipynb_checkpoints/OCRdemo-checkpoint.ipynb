# %%
import easyocr

# %%
reader = easyocr.Reader(['en','ru'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
import PIL
import os

# %%
###Вывод картиночки###
from PIL import ImageDraw
#im = PIL.Image.open('invoice1.png')
#im = PIL.Image.open('france.jfif')
#im = PIL.Image.open('1.png')
im = PIL.Image.open('eC-dulTAyEQ.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=609x599 at 0x192D388B160>

# %%
###Поиск текста в одной картинке###
bounds = reader.readtext('eC-dulTAyEQ.jpg')
#bounds = reader.readtext('france.jfif')
bounds
# Out:
# [([[391, 263], [516, 263], [516, 306], [391, 306]],
#   'молодой',
#   0.9538118243217468),
#  ([[351.15350102802535, 283.1219034952862],
#    [461.9792665231932, 296.6479048654408],
#    [457.84649897197465, 322.8780965047138],
#    [346.0207334768068, 310.3520951345592]],
#   'ЧЕловек,',
#   0.282868355512619),
#  ([[462, 296], [553, 296], [553, 329], [462, 329]],
#   'АЧТо у',
#   0.11308220028877258),
#  ([[379, 315], [520, 315], [520, 352], [379, 352]],
#   'BАС 8 Этом',
#   0.10162421315908432),
#  ([[379, 337], [514, 337], [514, 377], [379, 377]],
#   'ПАКЕТиКE?',
#   0.2830055058002472)]

# %%
for i in bounds:
    print(i[1])
# Out:
# молодой
# ЧЕловек,
# АЧТо у
# BАС 8 Этом
# ПАКЕТиКE?

# %%
###отрисовка коробочек в картиночке(имеются баги)###
def  draw_boxes(image,bounds,color='yellow',width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0,*p1,*p2,*p3,*p0], fill=color,width=width)
    return image

draw_boxes(im,bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=609x599 at 0x192D388B160>

# %%
for i in bounds:
    print(i[1])
# Out:
# молодой
# ЧЕловек,
# АЧТо у
# BАС 8 Этом
# ПАКЕТиКE?

# %%
###сортировка файликов в папочке###
unsorted_file_list = os.listdir()
sortetd_file_list = sorted(unsorted_file_list)
print(sortetd_file_list)
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', '1 (1).png', '1.png', 'IIe2N-Pr3pM.jpg', 'Nichosi.png', 'OCRdemo.ipynb', 'README.md', 'bitie.jpg', 'cbZzMQfm2i4.jpg', 'cmok.jpg', 'eC-dulTAyEQ.jpg', 'fat.png', 'france.jfif', 'hello.png', 'hto.png', 'jopajpg.jpg', 'kh.jpg', 'kill.png', 'medlenno.jpg', 'mnevr.jpg', 'musika.jpg', 'pagip.jpg', 'pizda.jpg', 'pozaza.png', 'road.jfif', 'shalavaa.jpg', 'solty.jpg', 'sori.jpg', 'teta.jpg', 'tusa.jpg']

# %%
type(sortetd_file_list)
# Out:
# list

# %%
###создание массивика только с картиночками###
image_list = []
for file in sortetd_file_list:
    if '.png' in file:
        image_list.append(file)
    elif '.jpg' in file:
        image_list.append(file)
    elif '.jpeg' in file:
        image_list.append(file)
    elif '.jfif' in file:
        image_list.append(file)
print(image_list)
# Out:
# %%
bounds_copy_list
for i in bounds_copy_list:
    i.remove(i[0])
    i.remove(i[1])
    

bounds_copy_list
# Out:
# [['молодой'], ['ЧЕловек,'], ['АЧТо у'], ['BАС 8 Этом'], ['ПАКЕТиКE?']]

# %%
pile_copy = pile.copy()
trash_list = []
#print(pile_copy)
for trash in pile_copy:
    trash = list(map(list,trash))
    #print(trash)
    trash_list.append(trash)
    '''
    for i in trash:
        i= list(map(list,i))
        print(i)
'''

#print(pile_copy)        
print(trash_list)
# Out:
# [[[[[28.194099619247982, 348.02500386989254], [445.9770309725526, 428.2275576802052], [417.805900380752, 534.9749961301075], [0.022969027447379275, 454.7724423197948]], 'QEUBEET!', 0.038893185555934906]], [[[[9.922678669848631, 103.19792908321288], [254.75835768399057, -17.79794114156195], [288.0773213301514, 72.80207091678712], [43.24164231600943, 194.79794114156195]], 'ЧУДЕСА', 0.48184075951576233]], [[[[72, 10], [472, 10], [472, 66], [72, 66]], 'взвукимагииз', 0.12006253749132156]], [[[[0, 0], [256, 0], [256, 64], [0, 64]], 'ничоси', 0.3176109790802002]], [[[[125, 131], [303, 131], [303, 193], [125, 193]], 'Бытие', 0.9574336409568787], [[[130, 191], [334, 191], [334, 229], [130, 229]], 'определяет', 0.9573479890823364], [[[150, 220], [314, 220], [314, 250], [150, 250]], 'сознание', 0.9500313401222229], [[[362, 258], [538, 258], [538, 290], [362, 290]], 'А сознание', 0.32657361030578613], [[[356, 282], [543, 282], [543, 346], [356, 346]], 'бытие', 0.9010838866233826], [[[315, 413], [353, 413], [353, 429], [315, 429]], '@81', 0.03489911928772926], [[[411, 557], [553, 557], [553, 593], [411, 593]], '00:01V/', 0.12732556462287903]], [[[[253.91611386505843, 6.373507435657778], [426.61797506541427, -6.10674064953035], [428.08388613494157, 44.62649256434222], [255.38202493458573, 58.10674064953035]], 'БитДк', 0.2174297571182251], [[[-0.13049516849970644, 32.73900966300059], [252.59471842202402, 4.65272734131349], [256.1304951684997, 65.26099033699941], [3.4052815779759964, 93.3472726586865]], 'сливайте', 0.5797218084335327], [[[131.70334646523148, 61.461712628310124], [503.17491335646906, 18.627207817033852], [507.29665353476855, 119.53828737168988], [135.82508664353097, 162.37279218296615]], 'глупцы', 0.851594865322113]], [[[[284, 251], [441, 251], [441, 308], [284, 308]], 'цмок*', 0.337100625038147]], [[[[391, 263], [516, 263], [516, 306], [391, 306]], 'молодой', 0.9538118243217468], [[[351.15350102802535, 283.1219034952862], [461.9792665231932, 296.6479048654408], [457.84649897197465, 322.8780965047138], [346.0207334768068, 310.3520951345592]], 'ЧЕловек,', 0.282868355512619], [[[462, 296], [553, 296], [553, 329], [462, 329]], 'АЧТо у', 0.11308220028877258], [[[379, 315], [520, 315], [520, 352], [379, 352]], 'BАС 8 Этом', 0.10162421315908432], [[[379, 337], [514, 337], [514, 377], [379, 377]], 'ПАКЕТиКE?', 0.2830055058002472]], [], [[[[35, 45], [195, 45], [195, 81], [35, 81]], 'Welcome
# %%
tr = []
for i in trash_list:
    i = sum(i,[])
    tr.append(i)
print(tr)
for i in tr:
    for j in i:
        j.lower()
print(tr)
# Out:
# [['QEUBEET!'], ['ЧУДЕСА'], ['взвукимагииз'], ['ничоси'], ['Бытие', 'определяет', 'сознание', 'А сознание', 'бытие', '@81', '00:01V/'], ['БитДк', 'сливайте', 'глупцы'], ['цмок*'], ['молодой', 'ЧЕловек,', 'АЧТо у', 'BАС 8 Этом', 'ПАКЕТиКE?'], [], ['Welcome to', 'France'], ['HELLO!'], ['Xт0 %?'], ['1ПО Жопе'], ['кукь'], ['IM A KILLER', ''], ['Медленно', 'пломо', 'и'], ['Bот это блять что за манёвр?', '17;32-', 'VK Tt"*', '89039 3;', '749"3183', 'Bsanuilore Серый'], ['наммузыкиажильомогЕг', 'нонЕвЧЕМ'], ['пагип', 'умир'], ['Иди', 'пизду', '8'], [], ['ATTENTION', 'PASSAGE', 'WILDlIFE', 'CROSSING', 'DдмIмдUх', 'surIZkm', 'nextI2km 7O', 'Gandrcigurs prp Iгилt', '5;*', '82'], ['модная шалавана башке  ОЗ;Зба'], ['10', 'кахуй', 'НУK', 'нарок', 'ПП|[3 375', 'ToPEEлG', '60201309', 'волевой'], ['соринко из', 'сладенького сегодня', 'толь(0 8', ':'], ['Пусть страшная', 'тетя уйдет!', '23:42 '], ['ПUBENEBAюю TуомTь!']]
# [['QEUBEET!'], ['ЧУДЕСА'], ['взвукимагииз'], ['ничоси'], ['Бытие', 'определяет', 'сознание', 'А сознание', 'бытие', '@81', '00:01V/'], ['БитДк', 'сливайте', 'глупцы'], ['цмок*'], ['молодой', 'ЧЕловек,', 'АЧТо у', 'BАС 8 Этом', 'ПАКЕТиКE?'], [], ['Welcome to', 'France'], ['HELLO!'], ['Xт0 %?'], ['1ПО Жопе'], ['кукь'], ['IM A KILLER', ''], ['Медленно', 'пломо', 'и'], ['Bот это блять что за манёвр?', '17;32-', 'VK Tt"*', '89039 3;', '749"3183', 'Bsanuilore Серый'], ['наммузыкиажильомогЕг', 'нонЕвЧЕМ'], ['пагип', 'умир'], ['Иди', 'пизду', '8'], [], ['ATTENTION', 'PASSAGE', 'WILDlIFE', 'CROSSING', 'DдмIмдUх', 'surIZkm', 'nextI2km 7O', 'Gandrcigurs prp Iгилt', '5;*', '82'], ['модная шалавана башке  ОЗ;Зба'], ['10', 'кахуй', 'НУK', 'нарок', 'ПП|[3 375', 'ToPEEлG', '60201309', 'волевой'], ['соринко из', 'сладенького сегодня', 'толь(0 8', ':'], ['Пусть страшная', 'тетя уйдет!', '23:42 '], ['ПUBENEBAюю TуомTь!']]

# %%
for trash in pile_copy:
    pile_copy.pop(trash[0][0])
print(pile_copy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-309-5579772212d6> in <module>
#       1 for trash in pile_copy:
# ----> 2     pile_copy.pop(trash[0][0])
#       3 print(pile_copy)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
###создание массивика строк найденых на картиночках###
ansvers = []
for i in pile:
    for j in i:
        ansvers.append(j[1])
print(ansvers)
# Out:
# ['QEUBEET!', 'ЧУДЕСА', 'взвукимагииз', 'ничоси', 'Бытие', 'определяет', 'сознание', 'А сознание', 'бытие', '@81', '00:01V/', 'БитДк', 'сливайте', 'глупцы', 'цмок*', 'молодой', 'ЧЕловек,', 'АЧТо у', 'BАС 8 Этом', 'ПАКЕТиКE?', 'Welcome to', 'France', 'HELLO!', 'Xт0 %?', '1ПО Жопе', 'кукь', 'IM A KILLER', '', 'Медленно', 'пломо', 'и', 'Bот это блять что за манёвр?', '17;32-', 'VK Tt"*', '89039 3;', '749"3183', 'Bsanuilore Серый', 'наммузыкиажильомогЕг', 'нонЕвЧЕМ', 'пагип', 'умир', 'Иди', 'пизду', '8', 'ATTENTION', 'PASSAGE', 'WILDlIFE', 'CROSSING', 'DдмIмдUх', 'surIZkm', 'nextI2km 7O', 'Gandrcigurs prp Iгилt', '5;*', '82', 'модная шалавана башке  ОЗ;Зба', '10', 'кахуй', 'НУK', 'нарок', 'ПП|[3 375', 'ToPEEлG', '60201309', 'волевой', 'соринко из', 'сладенького сегодня', 'толь(0 8', ':', 'Пусть страшная', 'тетя уйдет!', '23:42 ', 'ПUBENEBAюю TуомTь!']

# %%
trash_dict = {key: value for key, value in zip(image_list, tr)}
print(trash_dict)
# Out:
# {'1 (1).png': ['QEUBEET!'], '1.png': ['ЧУДЕСА'], 'IIe2N-Pr3pM.jpg': ['взвукимагииз'], 'Nichosi.png': ['ничоси'], 'bitie.jpg': ['Бытие', 'определяет', 'сознание', 'А сознание', 'бытие', '@81', '00:01V/'], 'cbZzMQfm2i4.jpg': ['БитДк', 'сливайте', 'глупцы'], 'cmok.jpg': ['цмок*'], 'eC-dulTAyEQ.jpg': ['молодой', 'ЧЕловек,', 'АЧТо у', 'BАС 8 Этом', 'ПАКЕТиКE?'], 'fat.png': [], 'france.jfif': ['Welcome to', 'France'], 'hello.png': ['HELLO!'], 'hto.png': ['Xт0 %?'], 'jopajpg.jpg': ['1ПО Жопе'], 'kh.jpg': ['кукь'], 'kill.png': ['IM A KILLER', ''], 'medlenno.jpg': ['Медленно', 'пломо', 'и'], 'mnevr.jpg': ['Bот это блять что за манёвр?', '17;32-', 'VK Tt"*', '89039 3;', '749"3183', 'Bsanuilore Серый'], 'musika.jpg': ['наммузыкиажильомогЕг', 'нонЕвЧЕМ'], 'pagip.jpg': ['пагип', 'умир'], 'pizda.jpg': ['Иди', 'пизду', '8'], 'pozaza.png': [], 'road.jfif': ['ATTENTION', 'PASSAGE', 'WILDlIFE', 'CROSSING', 'DдмIмдUх', 'surIZkm', 'nextI2km 7O', 'Gandrcigurs prp Iгилt', '5;*', '82'], 'shalavaa.jpg': ['модная шалавана башке  ОЗ;Зба'], 'solty.jpg': ['10', 'кахуй', 'НУK', 'нарок', 'ПП|[3 375', 'ToPEEлG', '60201309', 'волевой'], 'sori.jpg': ['соринко из', 'сладенького сегодня', 'толь(0 8', ':'], 'teta.jpg': ['Пусть страшная', 'тетя уйдет!', '23:42 '], 'tusa.jpg': ['ПUBENEBAюю TуомTь!']}

# %%
def get_key(d, value):
    for k, v in d.items():
        if v == value:
            return k

print(get_key(trash_dict,'QEUBEET!'))
# Out:
# 1 (1).png

# %%
###перебор словаря###
for i in trash_dict:
    trash_dict[i] = ' '.join(map(str,trash_dict[i]))
    trash_dict[i] = trash_dict[i].lower()
print(trash_dict)
# Out:
# {'1 (1).png': 'qeubeet!', '1.png': 'чудеса', 'IIe2N-Pr3pM.jpg': 'взвукимагииз', 'Nichosi.png': 'ничоси', 'bitie.jpg': 'бытие определяет сознание а сознание бытие @81 00:01v/', 'cbZzMQfm2i4.jpg': 'битдк сливайте глупцы', 'cmok.jpg': 'цмок*', 'eC-dulTAyEQ.jpg': 'молодой человек, ачто у bас 8 этом пакетикe?', 'fat.png': '', 'france.jfif': 'welcome to france', 'hello.png': 'hello!', 'hto.png': 'xт0 %?', 'jopajpg.jpg': '1по жопе', 'kh.jpg': 'кукь', 'kill.png': 'im a killer ', 'medlenno.jpg': 'медленно пломо и', 'mnevr.jpg': 'bот это блять что за манёвр? 17;32- vk tt"* 89039 3; 749"3183 bsanuilore серый', 'musika.jpg': 'наммузыкиажильомогег ноневчем', 'pagip.jpg': 'пагип умир', 'pizda.jpg': 'иди пизду 8', 'pozaza.png': '', 'road.jfif': 'attention passage wildlife crossing dдмiмдuх surizkm nexti2km 7o gandrcigurs prp iгилt 5;* 82', 'shalavaa.jpg': 'модная шалавана башке  оз;зба', 'solty.jpg': '10 кахуй нуk нарок пп|[3 375 topeeлg 60201309 волевой', 'sori.jpg': 'соринко из сладенького сегодня толь(0 8 :', 'teta.jpg': 'пусть страшная тетя уйдет! 23:42 ', 'tusa.jpg': 'пubenebaюю tуомtь!'}

# %%
### алгоритм левенштейна ####

str1 = 'привет'
str2 = 'пвте'

def dist(a,b):
    def rec(i,j):
        if i == 0 or j == 0:
            #если строка пустая, то расстояние равняется ее длине
            return max(i,j)
        elif a[i-1] == b[j-1]:
            #если последние символы одинаковые просто съедаем их
            return rec(i-1,j-1)
        else:
            #иначе считаем миимальный вариант
            return 1 + min(
            rec(i,j-1), #удаление символа
            rec(i-1,j), #вставка символа
            rec(i-1,j-1) # замена символа
            )
    
    return rec(len(a),len(b))


lev = dist(str1,str2)

print(str(lev))
# Out:
# 4

# %%
lev_dict = {}
x = str(input()).lower()
####поиск картинки###
for i in trash_dict:
    klev = simil(trash_dict[i],x)
    lev_dict[klev] = i
print(lev_dict)
res = PIL.Image.open(lev_dict[max(lev_dict)])
res
#print(lev_dict)
# Out:
# сливайте
# {0.0: 'tusa.jpg', 0.14285714285714285: 'hto.png', 0.2: 'IIe2N-Pr3pM.jpg', 0.06451612903225806: 'bitie.jpg', 0.5517241379310345: 'cbZzMQfm2i4.jpg', 0.11538461538461539: 'eC-dulTAyEQ.jpg', 0.125: 'jopajpg.jpg', 0.08333333333333333: 'medlenno.jpg', 0.046511627906976744: 'mnevr.jpg', 0.10810810810810811: 'musika.jpg', 0.1111111111111111: 'pagip.jpg', 0.10526315789473684: 'pizda.jpg', 0.019801980198019802: 'road.jfif', 0.21621621621621623: 'shalavaa.jpg', 0.09836065573770492: 'solty.jpg', 0.16326530612244897: 'sori.jpg', 0.1951219512195122: 'teta.jpg'}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=509x520 at 0x19284325730>

# %%
lev_dict = {}
test_dict = {'1 (1).png': 'qeubeet!', '1.png': 'чудеса', 'IIe2N-Pr3pM.jpg': 'взвукимагииз', 'Nichosi.png': 'ничоси', 'bitie.jpg': 'бытие определяет сознание а сознание бытие @81 00:01v/', 'cbZzMQfm2i4.jpg': 'битдк сливайте глупцы', 'cmok.jpg': 'цмок*', 'eC-dulTAyEQ.jpg': 'молодой человек, ачто у bас 8 этом пакетикe?', 'fat.png': '',}
x = str(input())
####поиск картинки###
for i in test_dict:
    klev = dist(test_dict[i],x)
    lev_dict[klev] = test_dict[i]
print(lev_dict)
# Out:
# {8: 'qeubeet!', 6: 'ничоси', 12: 'взвукимагииз', 54: 'бытие определяет сознание а сознание бытие @81 00:01v/', 21: 'битдк сливайте глупцы', 5: 'цмок*', 44: 'молодой человек, ачто у bас 8 этом пакетикe?', 0: ''}

# %%
###Расстояние Левенштейна###
from functools import lru_cache

# %%
def my_dist_cached(a, b):
    @lru_cache(maxsize=len(a) * len(b))
    def recursive(i, j):
        if i == 0 or j == 0:
            return max(i, j)
        elif a[i - 1] == b[j - 1]:
            return recursive(i - 1, j - 1)
        else:
            return 1 + min(
                recursive(i, j - 1),
                recursive(i - 1, j),
                recursive(i - 1, j - 1)
            )
    return recursive(len(a), len(b))

# %%
###Коэфициент Танимото###
def tanimoto(s1, s2):
    a, b, c = len(s1), len(s2), 0.0

    for sym in s1:
        if sym in s2:
            c += 1

    return c / (a + b - c)

# %%
###Дифлиб###
import difflib

def simil(s1,s2):
    matcher = difflib.SequenceMatcher(None, s1, s2)
    return matcher.ratio()

# %%
from __future__ import barry_as_FLUFL
def predkompil2(x):
    d = {0:0}
    for i in xrange(1,len(x)):
        j = d[i-1]#эту строку мы заменили
        while j > 0 and x[j] <> x[i]:
            j = d[j-1]
        if x[j] == x[i]:
            j += 1
        d[i] = j
    return d
# Out:
#   File "<ipython-input-398-5a42531d73ad>", line 6
#     while j > 0 and x[j] <> x[i]:
#                           ^
# SyntaxError: invalid syntax

# %%
knutt = KnuthMorrisPratt('модная шалавана башке  оз;зба', 'мдная шалава')

# %%
def kmpSearch(s, x):
    d = predkompil2(x)
    i = j = 0
    while i<len(s) and j<len(x):
        if x[j] == s[i]:
            i+=1
            j+=1
        elif j==0:
            i+=1
        else:
            j = d[j-1]
    else:
        if j == len(x):
            return i-j
        return None
